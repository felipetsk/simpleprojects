# %% [markdown]
# <a href="https://colab.research.google.com/github/felipetsk/simpleprojects/blob/main/Exercicio_aula02_felipe_martins.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Felipe Linhares Martins // RID: 8800331188

# %%
import matplotlib.pyplot as plt

idade = [18, 21, 53, 20, 25, 18]

nomes = ['Marcos', 'Felipe', 'Jonas', 'Paulo', 'Claudio', 'Brisamar']

valores = []


plt.figure(figsize= (18,10))
plt.bar(nomes, idade)
# Out:
# <BarContainer object of 6 artists>

# %%
valores = []

for i in nomes:
  valores.append(int(input('Quanto {} deseja ganhar?: '.format(i))))

print(valores)
# Out:
# Quanto Marcos deseja ganhar?: 300
# Quanto Felipe deseja ganhar?: 400
# Quanto Jonas deseja ganhar?: 500
# Quanto Paulo deseja ganhar?: 600
# Quanto Claudio deseja ganhar?: 700
# Quanto Brisamar deseja ganhar?: 800
# [300, 400, 500, 600, 700, 800]

# %%
plt.figure(figsize= (18,10))
plt.bar(nomes,valores)
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# # Nome: Felipe Linhares Martins
# # RID: 8800331188
# # Link: https://colab.research.google.com/drive/15RPX3erQHFj7DPu4zdXYBzlGyMEcJy8v?usp=sharing
